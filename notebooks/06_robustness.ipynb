# %% [markdown]
# # 06 — Phase 6 robustness sweep
#
# 30 specifications: V-Dem sub-indices, WGI swap, gini_mkt swap, WID top 10 % swap, SWIID 10-imputation Rubin's-rules average, sub-samples, lag sensitivity, period sensitivity. Headline corruption → inequality at lag 1 rejects H₀ at 1 % in every spec.

# %%
import os; os.chdir('..')
import sys; sys.path.insert(0,'.')
from src.tests.run_phase6 import main as phase6_main
phase6_main()

# %%
from src.utils.robustness_fig import main as fig_main
fig_main()

# %%
from IPython.display import Image
Image(filename='outputs/figures/fig06_robustness_heatmap.png')

# %%
import pandas as pd
rm = pd.read_csv('outputs/tables/robustness_matrix.csv')
print(rm.to_string(index=False))
