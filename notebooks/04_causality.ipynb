# %% [markdown]
# # 04 — Phase 4 causality tests
#
# Dumitrescu–Hurlin with Lopez–Weber year-block bootstrap (Phase 4 a) and Toda–Yamamoto country-by-country (Phase 4 b). Bootstrap is the headline because Phase-2 CD test rejected cross-sectional independence on every variable.

# %%
import os; os.chdir('..')
import sys; sys.path.insert(0,'.')
from src.tests.run_phase4 import main
main()

# %%
import pandas as pd
for t in ['dh_results','ty_summary','ty_results']:
    print('---',t,'---')
    print(pd.read_csv(f'outputs/tables/{t}.csv').head(15).to_string(index=False))
    print()
