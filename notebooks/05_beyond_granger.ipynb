# %% [markdown]
# # 05 — Phase 5 beyond Granger
#
# Panel local projections (Jordà 2005) with country + year FE and clustered SEs, both directions. Brazil Lava Jato 2014 synthetic control with a Latin-America donor pool.

# %%
import os; os.chdir('..')
import sys; sys.path.insert(0,'.')
from src.models.run_phase5 import main
main()

# %%
from IPython.display import Image
Image(filename='outputs/figures/fig05_lp_irfs.png')

# %%
Image(filename='outputs/figures/fig05_case_brazil.png')
